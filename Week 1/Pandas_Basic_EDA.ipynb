# %% [markdown]
# # Basic EDA with Pandas

# %%
import pandas as pd

# %%
DataFrame = pd.read_csv('../Data/hotel_bookings.csv')

# %%
DataFrame
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df_shape = pd.DataFrame([DataFrame.shape], columns=['jumlah baris', 'jumlah kolom'])
df_shape
# Out:
#    jumlah baris  jumlah kolom
# 0        119390            32

# %%
DataFrame.shape
# Out:
# (119390, 32)

# %%
# .head()

DataFrame.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
# .tail()

DataFrame.tail(10)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# 119384  City Hotel            0         21               2017
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119380             August                        35
# 119381             August                        35
# 119382             August                        35
# 119383             August                        35
# ...

# %%
# .sample

DataFrame.sample(5)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 116524    City Hotel            0         15               2017
# 62080     City Hotel            1         46               2017
# 16638   Resort Hotel            0         47               2015
# 63967     City Hotel            1         18               2017
# 69701     City Hotel            1        173               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 116524               July                        29
# 62080             January                         1
# 16638              August                        36
# 63967            February                         8
# 69701                June                        23
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 116524                         20                        0
# 62080                           1                        2
# 16638                          30                        2
# ...

# %%
# .columns
df_columns = pd.DataFrame(DataFrame.columns, columns=['Nama Kolom'])
df_columns
# Out:
#                         Nama Kolom
# 0                            hotel
# 1                      is_canceled
# 2                        lead_time
# 3                arrival_date_year
# 4               arrival_date_month
# 5         arrival_date_week_number
# 6        arrival_date_day_of_month
# 7          stays_in_weekend_nights
# 8             stays_in_week_nights
# 9                           adults
# 10                        children
# 11                          babies
# 12                            meal
# 13                         country
# 14                  market_segment
# 15            distribution_channel
# 16               is_repeated_guest
# 17          previous_cancellations
# 18  previous_bookings_not_canceled
# 19              reserved_room_type
# 20              assigned_room_type
# 21                 booking_changes
# 22                    deposit_type
# 23                           agent
# 24                         company
# 25            days_in_waiting_list
# ...

# %%
# .dtypes
df_tipeData = pd.DataFrame(DataFrame.dtypes, columns=['Tipe Data'])
df_tipeData
# Out:
#                                Tipe Data
# hotel                             object
# is_canceled                        int64
# lead_time                          int64
# arrival_date_year                  int64
# arrival_date_month                object
# arrival_date_week_number           int64
# arrival_date_day_of_month          int64
# stays_in_weekend_nights            int64
# stays_in_week_nights               int64
# adults                             int64
# children                         float64
# babies                             int64
# meal                              object
# country                           object
# market_segment                    object
# distribution_channel              object
# is_repeated_guest                  int64
# previous_cancellations             int64
# previous_bookings_not_canceled     int64
# reserved_room_type                object
# assigned_room_type                object
# booking_changes                    int64
# ...

# %%
# .info()
DataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
DataFrame['agent']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3         304.0
# 4         240.0
#           ...
# 119385    394.0
# 119386      9.0
# 119387      9.0
# 119388     89.0
# 119389      9.0
# Name: agent, Length: 119390, dtype: float64

# %%
# .describe()
DataFrame.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ## Data Cleaning
# missing value

# %%
# .isnull().sum()
DataFrame.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# kita ubah ke persentase
DataFrame.isnull().sum() / len(DataFrame) * 100
# Out:
# hotel                              0.000000
# is_canceled                        0.000000
# lead_time                          0.000000
# arrival_date_year                  0.000000
# arrival_date_month                 0.000000
# arrival_date_week_number           0.000000
# arrival_date_day_of_month          0.000000
# stays_in_weekend_nights            0.000000
# stays_in_week_nights               0.000000
# adults                             0.000000
# children                           0.003350
# babies                             0.000000
# meal                               0.000000
# country                            0.408744
# market_segment                     0.000000
# distribution_channel               0.000000
# is_repeated_guest                  0.000000
# previous_cancellations             0.000000
# previous_bookings_not_canceled     0.000000
# reserved_room_type                 0.000000
# assigned_room_type                 0.000000
# ...

# %%
# mengisi datanya -> Unknown -> .fillna()
DataFrame['country'] = DataFrame['country'].fillna('Unknown')

# %%
DataFrame.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                                0
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
DataFrame['children'].sample(5)
# Out:
# 35946    0.0
# 56093    0.0
# 61244    0.0
# 50993    0.0
# 75799    0.0
# Name: children, dtype: float64

# %%
DataFrame['children'] = DataFrame['children'].fillna(0)

# %%
DataFrame.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               0
# babies                                 0
# meal                                   0
# country                                0
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
DataFrame['agent'] = DataFrame['agent'].fillna(0)

# %%
DataFrame.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               0
# babies                                 0
# meal                                   0
# country                                0
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
DataFrameNew = DataFrame.drop(columns=['company'], axis=1)

# %%
DataFrameNew.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
# Duplicate Data -> .duplicated()
DataFrameNew.duplicated().sum()
# Out:
# np.int64(32001)

# %%
DataFrameNew[DataFrameNew.duplicated].head(10)
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 5    Resort Hotel            0         14               2015
# 22   Resort Hotel            0         72               2015
# 43   Resort Hotel            0         70               2015
# 138  Resort Hotel            1          5               2015
# 200  Resort Hotel            0          0               2015
# 219  Resort Hotel            1          1               2015
# 256  Resort Hotel            0         91               2015
# 261  Resort Hotel            0         30               2015
# 353  Resort Hotel            0         98               2015
# 372  Resort Hotel            0         40               2015
#
#     arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 5                 July                        27                          1
# 22                July                        27                          1
# ...

# %%
# drop_duplicates()
DataFrameNew.drop_duplicates(inplace=True)

# %%
DataFrameNew
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# # Aggregation & Feature Engineering

# %%
# df.groupby()
DataFrameNew.groupby('hotel')['is_canceled'].value_counts().unstack()
# Out:
# is_canceled       0      1
# hotel
# City Hotel    37377  16049
# Resort Hotel  25987   7976

# %%
df_columns
# Out:
#                         Nama Kolom
# 0                            hotel
# 1                      is_canceled
# 2                        lead_time
# 3                arrival_date_year
# 4               arrival_date_month
# 5         arrival_date_week_number
# 6        arrival_date_day_of_month
# 7          stays_in_weekend_nights
# 8             stays_in_week_nights
# 9                           adults
# 10                        children
# 11                          babies
# 12                            meal
# 13                         country
# 14                  market_segment
# 15            distribution_channel
# 16               is_repeated_guest
# 17          previous_cancellations
# 18  previous_bookings_not_canceled
# 19              reserved_room_type
# 20              assigned_room_type
# 21                 booking_changes
# 22                    deposit_type
# 23                           agent
# 24                         company
# 25            days_in_waiting_list
# ...

# %%
DataFrameNew.groupby('hotel')['adr'].mean()
# Out:
# hotel
# City Hotel      110.985270
# Resort Hotel     99.030296
# Name: adr, dtype: float64

# %%
DataFrameNew.groupby(['arrival_date_year', 'hotel'])['adr'].mean().unstack()
# Out:
# hotel              City Hotel  Resort Hotel
# arrival_date_year
# 2015                89.813927     94.450802
# 2016               107.896446     90.653587
# 2017               121.986516    113.020094

# %%
DataFrameNew.groupby('customer_type')['lead_time'].aggregate(['min', 'max', 'mean', 'count'])
# Out:
#                  min  max        mean  count
# customer_type
# Contract           0  532  109.225231   3139
# Group              0  468   51.584559    544
# Transient          0  737   73.431274  71982
# Transient-Party    0  542  113.057489  11724

# %% [markdown]
# ## Feature Engineering
# nambah data dari data yang kita miliki

# %%
DataFrameNew['total_nights'] = DataFrameNew['stays_in_weekend_nights'] + DataFrameNew['stays_in_week_nights']

# %%
DataFrameNew[['total_nights', 'stays_in_weekend_nights', 'stays_in_week_nights']].sample(10)
# Out:
#         total_nights  stays_in_weekend_nights  stays_in_week_nights
# 26027              5                        2                     3
# 117554             4                        0                     4
# 21010              1                        1                     0
# 85031              4                        2                     2
# 35002             10                        3                     7
# 116572             1                        0                     1
# 56740              2                        1                     1
# 26871              7                        2                     5
# 71304             11                        4                     7
# 112732             3                        0                     3

# %%
df_columns
# Out:
#                         Nama Kolom
# 0                            hotel
# 1                      is_canceled
# 2                        lead_time
# 3                arrival_date_year
# 4               arrival_date_month
# 5         arrival_date_week_number
# 6        arrival_date_day_of_month
# 7          stays_in_weekend_nights
# 8             stays_in_week_nights
# 9                           adults
# 10                        children
# 11                          babies
# 12                            meal
# 13                         country
# 14                  market_segment
# 15            distribution_channel
# 16               is_repeated_guest
# 17          previous_cancellations
# 18  previous_bookings_not_canceled
# 19              reserved_room_type
# 20              assigned_room_type
# 21                 booking_changes
# 22                    deposit_type
# 23                           agent
# 24                         company
# 25            days_in_waiting_list
# ...

# %%
DataFrameNew['is_repeated_guest_category'] = DataFrameNew['is_repeated_guest'].apply(lambda x: 'Yes' if x == 1 else 'No')

# %%
DataFrameNew[['is_repeated_guest_category', 'is_repeated_guest']].sample(10)
# Out:
#        is_repeated_guest_category  is_repeated_guest
# 57177                          No                  0
# 66073                          No                  0
# 21101                          No                  0
# 101533                         No                  0
# 73530                          No                  0
# 29347                          No                  0
# 31091                          No                  0
# 56291                          No                  0
# 100558                         No                  0
# 21898                          No                  0

# %%
DataFrameNew['reservation_status_date'] = pd.to_datetime(DataFrameNew['reservation_status_date']) #string to bject datetime
# Mengekstrak nama bulan dari tanggal tersebut.
DataFrameNew['month_of_reservation_status'] = DataFrameNew['reservation_status_date'].dt.month_name()
DataFrameNew[['reservation_status_date', 'month_of_reservation_status']].head()
# Out:
#   reservation_status_date month_of_reservation_status
# 0              2015-07-01                        July
# 1              2015-07-01                        July
# 2              2015-07-02                        July
# 3              2015-07-02                        July
# 4              2015-07-03                        July

# %%
DataFrameNew['reservation_status_date']
# Out:
# 0        2015-07-01
# 1        2015-07-01
# 2        2015-07-02
# 3        2015-07-02
# 4        2015-07-03
#             ...
# 119385   2017-09-06
# 119386   2017-09-07
# 119387   2017-09-07
# 119388   2017-09-07
# 119389   2017-09-07
# Name: reservation_status_date, Length: 87389, dtype: datetime64[ns]

# %%
DataFrameNew['arrival_date_month']
# Out:
# 0           July
# 1           July
# 2           July
# 3           July
# 4           July
#            ...
# 119385    August
# 119386    August
# 119387    August
# 119388    August
# 119389    August
# Name: arrival_date_month, Length: 87389, dtype: object

# %%
# .map()
month_mapping = {
    'January': 1, 'February': 2, 'March': 3,
    'April': 4, 'May': 5, 'June': 6,
    'July': 7, 'August': 8, 'September': 9,
    'October': 10, 'November': 11, 'December': 12
}

DataFrameNew['arrival_date_month'] = DataFrameNew['arrival_date_month'].map(month_mapping)

# %%
DataFrameNew['arrival_date_month']
# Out:
# 0         7
# 1         7
# 2         7
# 3         7
# 4         7
#          ..
# 119385    8
# 119386    8
# 119387    8
# 119388    8
# 119389    8
# Name: arrival_date_month, Length: 87389, dtype: int64

# %%
# (boolean) -> lamda, (multiclas) -> map

# %%
# DataFrameNew['arrival_in_jan'] = DataFrameNew['arrival_date_month'].apply(lambda x: 1 if x == 'January' else 0)

# %%
# DataFrameNew['arrival_in_jan'].sample(10)

# %%
DataFrameNew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87389 entries, 0 to 119389
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87389 non-null  object
#  1   is_canceled                     87389 non-null  int64
#  2   lead_time                       87389 non-null  int64
#  3   arrival_date_year               87389 non-null  int64
#  4   arrival_date_month              87389 non-null  int64
#  5   arrival_date_week_number        87389 non-null  int64
#  6   arrival_date_day_of_month       87389 non-null  int64
#  7   stays_in_weekend_nights         87389 non-null  int64
#  8   stays_in_week_nights            87389 non-null  int64
#  9   adults                          87389 non-null  int64
#  10  children                        87389 non-null  float64
#  11  babies                          87389 non-null  int64
# ...

# %% [markdown]
# # Advanced Data Preprocessing

# %%
DataFrameNew.head(10)
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2015
# 1   Resort Hotel            0        737               2015
# 2   Resort Hotel            0          7               2015
# 3   Resort Hotel            0         13               2015
# 4   Resort Hotel            0         14               2015
# 6   Resort Hotel            0          0               2015
# 7   Resort Hotel            0          9               2015
# 8   Resort Hotel            1         85               2015
# 9   Resort Hotel            1         75               2015
# 10  Resort Hotel            1         23               2015
#
#     arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                    7                        27                          1
# 1                    7                        27                          1
# ...

# %%
DataFrameNew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87389 entries, 0 to 119389
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87389 non-null  object
#  1   is_canceled                     87389 non-null  int64
#  2   lead_time                       87389 non-null  int64
#  3   arrival_date_year               87389 non-null  int64
#  4   arrival_date_month              87389 non-null  int64
#  5   arrival_date_week_number        87389 non-null  int64
#  6   arrival_date_day_of_month       87389 non-null  int64
#  7   stays_in_weekend_nights         87389 non-null  int64
#  8   stays_in_week_nights            87389 non-null  int64
#  9   adults                          87389 non-null  int64
#  10  children                        87389 non-null  float64
#  11  babies                          87389 non-null  int64
# ...

# %%
numerical_cols = DataFrameNew.select_dtypes(include=['int64', 'float64']).columns.to_list()

# %%
def remove_outliers_iqr(df, columns, x):
    df_clean = df.copy()
    for col in columns:
        Q1 = df_clean[col].quantile(0.25)
        Q3 = df_clean[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - x * IQR # 1.5
        upper_bound = Q3 + x * IQR # 1.5
        df_clean = df_clean[(df_clean[col] >= lower_bound) & (df_clean[col] <= upper_bound)]
    return df_clean

# %%
df_no_outliers = remove_outliers_iqr(DataFrameNew, numerical_cols, 2)

# %%
df_no_outliers
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 4       Resort Hotel            0         14               2015
# 6       Resort Hotel            0          0               2015
# 7       Resort Hotel            0          9               2015
# 8       Resort Hotel            1         85               2015
# 9       Resort Hotel            1         75               2015
# ...              ...          ...        ...                ...
# 119384    City Hotel            0         21               2017
# 119385    City Hotel            0         23               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#         arrival_date_month  arrival_date_week_number  \
# 4                        7                        27
# 6                        7                        27
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df_minmax_scaled = df_no_outliers.copy()

# %%
min_max_scale = MinMaxScaler()

# %%
df_minmax_scaled[numerical_cols] = min_max_scale.fit_transform(df_no_outliers[numerical_cols])

# %%
df_minmax_scaled.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  arrival_date_month  \
# count  41264.000000  41264.000000       41264.000000        41264.000000
# mean       0.313978      0.229539           0.612313            0.492368
# min        0.000000      0.000000           0.000000            0.000000
# 25%        0.000000      0.050992           0.500000            0.272727
# 50%        0.000000      0.161473           0.500000            0.454545
# 75%        1.000000      0.354108           1.000000            0.727273
# max        1.000000      1.000000           1.000000            1.000000
# std        0.464113      0.219232           0.341537            0.276249
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              41264.000000               41264.000000
# mean                   0.491431                   0.491466
# min                    0.000000                   0.000000
# 25%                    0.288462                   0.233333
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
std_scaler = StandardScaler()

# %%
df_std_scaled = df_no_outliers.copy()
df_std_scaled[numerical_cols] = std_scaler.fit_transform(df_no_outliers[numerical_cols])

# %%
df_std_scaled.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  arrival_date_month  \
# count  4.126400e+04  4.126400e+04       4.126400e+04        4.126400e+04
# mean   2.892865e-17 -6.405630e-17      -7.430806e-14        1.074493e-16
# min   -6.765204e-01 -1.047028e+00      -1.792838e+00       -1.782354e+00
# 25%   -6.765204e-01 -8.144338e-01      -3.288507e-01       -7.950922e-01
# 50%   -6.765204e-01 -3.104794e-01      -3.288507e-01       -1.369177e-01
# 75%    1.478152e+00  5.682104e-01       1.135136e+00        8.503442e-01
# max    1.478152e+00  3.514406e+00       1.135136e+00        1.837606e+00
# std    1.000012e+00  1.000012e+00       1.000012e+00        1.000012e+00
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              4.126400e+04               4.126400e+04
# mean              -4.545931e-17              -1.102044e-17
# min               -1.902764e+00              -1.662604e+00
# 25%               -7.858739e-01              -8.732500e-01
# ...

# %%
from sklearn.preprocessing import RobustScaler

# %%
robust_scale = RobustScaler()

# %%
df_robust_scaled = df_no_outliers.copy()
df_robust_scaled[numerical_cols] = robust_scale.fit_transform(df_no_outliers[numerical_cols])

# %%
df_robust_scaled.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  arrival_date_month  \
# count  41264.000000  41264.000000       41264.000000        41264.000000
# mean       0.313978      0.224555           0.224627            0.083211
# min        0.000000     -0.532710          -1.000000           -1.000000
# 25%        0.000000     -0.364486           0.000000           -0.400000
# 50%        0.000000      0.000000           0.000000            0.000000
# 75%        1.000000      0.635514           1.000000            0.600000
# max        1.000000      2.766355           1.000000            1.200000
# std        0.464113      0.723261           0.683074            0.607749
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              41264.000000               41264.000000
# mean                  -0.021219                  -0.016001
# min                   -1.238095                  -0.937500
# 25%                   -0.523810                  -0.500000
# ...

# %%
# .corr()
DataFrameNew[numerical_cols].corr()
# Out:
#                                 is_canceled  lead_time  arrival_date_year  \
# is_canceled                        1.000000   0.184772           0.088021
# lead_time                          0.184772   1.000000           0.139123
# arrival_date_year                  0.088021   0.139123           1.000000
# arrival_date_month                 0.003735   0.106216          -0.499849
# arrival_date_week_number           0.001469   0.101195          -0.514194
# arrival_date_day_of_month          0.005317   0.009852          -0.010073
# stays_in_weekend_nights            0.060159   0.235109           0.005127
# stays_in_week_nights               0.082886   0.310088           0.003623
# adults                             0.081775   0.140439           0.038573
# children                           0.067355   0.028630           0.041153
# babies                            -0.020548  -0.003620          -0.023338
# is_repeated_guest                 -0.089654  -0.147021           0.024339
# ...
